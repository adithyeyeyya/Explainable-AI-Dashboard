# %%
import pandas as pd

# Load your CSV file
df = pd.read_csv('"C:/Users/Adithya/Downloads/loan_approval_dataset.csv"')  # Replace with your actual file name

# Map the loan_status column to binary values
# Assuming you have categories like 'Approved'/'Denied' or 'Paid'/'Default'
# Modify the dictionary values to match your specific categories
status_mapping = {
    'Approved': 1,  # Replace with your actual category names
    'Denied': 0,    # Replace with your actual category names
    # Add more mappings if you have more than two categories
}

# Apply the mapping to create a new binary column
df['loan_status_binary'] = df['loan_status'].map(status_mapping)

# If you want to replace the original column instead of adding a new one, use:
# df['loan_status'] = df['loan_status'].map(status_mapping)

# Save the modified dataframe to a new CSV file
df.to_csv('modified_loan_data.csv', index=False)

print("Conversion complete. New file saved as 'modified_loan_data.csv'")
